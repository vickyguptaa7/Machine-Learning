# %%
import cv2  
import matplotlib.pyplot as plt

# %%
img =cv2.imread('dog.jpeg');
print(img.shape)
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Out:
# (1197, 1200, 3)

# %%
# show the image
plt.axis("off")
plt.imshow(new_img)
